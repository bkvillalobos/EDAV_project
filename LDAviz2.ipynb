# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, PCA
from sklearn.cluster import KMeans

import pandas as pd
import nltk
import nltk.data

# %%
df = 'townhall.txt'


tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
fp = open("townhall.txt")
data = fp.read()

df ='\n\n'.join(tokenizer.tokenize(data))

df = df.split("\n\n")   


topics_no = 4
range_t = topics_no + 1

vectorizer = CountVectorizer(stop_words="english", ngram_range=(2,2))
vectorized = vectorizer.fit_transform(df)


lda = LatentDirichletAllocation(n_topics=topics_no, learning_method='batch')
lda.fit(vectorized)
# Out:
# /anaconda2/lib/python2.7/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=1, n_topics=4, perp_tol=0.1,
#              random_state=None, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
import PyPDF2
import csv

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from gensim import corpora
from gensim.models import LdaModel

import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, PCA
from sklearn.cluster import KMeans

import pyLDAvis.gensim

def biphrase_preprocess(tokens, deacc=True, lowercase=True, errors='ignore',
    stemmer=None, stopwords=None):
    
    biphrases = []

    if len(tokens) >1:
        for i in range(0,len(tokens)-1):
            yield tokens[i] + '_' + tokens[i+1]

#nltk.download()

# %%
df 

documents = df

from sklearn.feature_extraction import stop_words

stop = list(stop_words.ENGLISH_STOP_WORDS)

banned = ["applause", "tell", "let", "want", "know", 
 "let", "got", "don", "sir", "yes", "little", "question", "ask", "answer", "said", "goin", "don", "lapido", "ll", "want", "bring", "" "us", "go", "also", "lot", "'s", "'re", "n't", "'m", "going", "--_--", "—", "--", "'ve", "ve"]



banned_total = set(stop + banned)

texts = [word_tokenize(doc)  for doc in documents]
texts_lower = [[word.lower() for word in text] for text in texts]
uniphrases = [[word for word in text if not word.isdigit() and word not in banned_total and len(word) > 1] for text in texts_lower]

biphrases = [[biphrase for biphrase in biphrase_preprocess(text)] for text in uniphrases]

dictionary_biphrases = corpora.Dictionary(biphrases, prune_at=20000000)
dictionary_biphrases.save_as_text('gensim_dict_biphrases.txt')

# %%
corpus = [dictionary_biphrases.doc2bow(text) for text in biphrases]
lda = LdaModel(corpus, num_topics=4, id2word=dictionary_biphrases)

pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(lda, corpus, dictionary_biphrases)
# Out:
# /anaconda2/lib/python2.7/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      29.226612        1       1  0.103056 -0.022576
# 3      24.606941        1       2 -0.007570  0.082926
# 2      24.345607        1       3 -0.048527 -0.076728
# 0      21.820839        1       4 -0.046959  0.016378, topic_info=     Category       Freq                  Term      Total  loglift  logprob
# term
# 2484  Default  10.000000        senator_nelson  10.000000  30.0000  30.0000
# 17    Default   4.000000                gon_na   4.000000  29.0000  29.0000
# 2156  Default  11.000000      stoneman_douglas  11.000000  28.0000  28.0000
# 3273  Default   3.000000             nra_money   3.000000  27.0000  27.0000
# 3193  Default   3.000000         thank_senator   3.000000  26.0000  26.0000
# 2399  Default   3.000000         serve_country   3.000000  25.0000  25.0000
# 64    Default   3.000000    congressman_deutch   3.000000  24.0000  24.0000
# 2284  Default   2.000000         rubio_support   2.000000  23.0000  23.0000
# 818   Default   4.000000         ..._crosstalk   4.000000  22.0000  22.0000
# 2717  Default   2.000000             kasky_...   2.000000  21.0000  21.0000
# 276   Default   2.000000        innocent_lives   2.000000  20.0000  20.0000
# 3728  Default   2.000000             swat_team   2.000000  19.0000  19.0000
# 877   Default  13.000000         senator_rubio  13.000000  18.0000  18.0000
# 3213  Default   2.000000      immediate_threat   2.000000  17.0000  17.0000
# 3     Default   2.000000        county_sheriff   2.000000  16.0000  16.0000
# 257   Default   2.000000           school_safe   2.000000  15.0000  15.0000
# 2759  Default   2.000000         make_decision   2.000000  14.0000  14.0000
# 378   Default   2.000000         rubio_senator   2.000000  13.0000  13.0000
# 2573  Default   5.000000       assault_weapons   5.000000  12.0000  12.0000
# 1727  Default   2.000000         rubio_believe   2.000000  11.0000  11.0000
# 3081  Default   2.000000        believe_saying   2.000000  10.0000  10.0000
# 2326  Default   2.000000           safe_school   2.000000   9.0000   9.0000
# 3196  Default   2.000000                5k_run   2.000000   8.0000   8.0000
# 1627  Default   2.000000           kids_school   2.000000   7.0000   7.0000
# 1538  Default   2.000000         school_school   2.000000   6.0000   6.0000
# 1622  Default   2.000000        teachers_armed   2.000000   5.0000   5.0000
# 1566  Default   5.000000          douglas_high   5.000000   4.0000   4.0000
# 973   Default   2.000000          thank_coming   2.000000   3.0000   3.0000
# 2167  Default   2.000000      crosstalk_tapper   2.000000   2.0000   2.0000
# 255   Default   2.000000       earlier_tonight   2.000000   1.0000   1.0000
# ...       ...        ...                   ...        ...      ...      ...
# 3768   Topic4   1.130252        charged_felony   1.550690   1.2060  -6.8044
# 2408   Topic4   1.130167            nra_future   1.550689   1.2060  -6.8045
# 922    Topic4   1.129738              guys_...   1.550769   1.2055  -6.8048
# 3779   Topic4   1.127453            kasky_guys   1.550910   1.2034  -6.8069
# 2930   Topic4   1.124290          america_safe   1.551180   1.2004  -6.8097
# 373    Topic4   1.117042            did_report   1.551710   1.1936  -6.8161
# 317    Topic4   1.115412            lives_lost   1.551882   1.1921  -6.8176
# 1059   Topic4   1.109774              na_night   1.552454   1.1866  -6.8227
# 3696   Topic4   1.107217     thank_congressman   1.552514   1.1843  -6.8250
# 2450   Topic4   1.089702          deutch_great   1.554395   1.1671  -6.8409
# 3273   Topic4   2.120493             nra_money   3.099107   1.1428  -6.1752
# 2918   Topic4   1.039680          people_right   1.556165   1.1190  -6.8879
# 629    Topic4   1.034821        eighth_tragedy   1.556097   1.1144  -6.8926
# 871    Topic4   1.018256       terrorist_watch   1.559732   1.0959  -6.9087
# 17     Topic4   2.684405                gon_na   4.213476   1.0715  -5.9394
# 2167   Topic4   1.318814      crosstalk_tapper   2.075752   1.0687  -6.6501
# 255    Topic4   1.309872       earlier_tonight   2.075502   1.0620  -6.6569
# 360    Topic4   0.631204  ratified_declaration   1.044322   1.0188  -7.3869
# 1957   Topic4   0.929634            watch_list   1.566438   1.0005  -6.9998
# 818    Topic4   2.306151         ..._crosstalk   4.201783   0.9224  -6.0912
# 2093   Topic4   2.018716           bump_stocks   4.219455   0.7851  -6.2244
# 2015   Topic4   2.629753          tapper_thank   7.480183   0.4769  -5.9599
# 3517   Topic4   2.124080             make_sure   6.970604   0.3339  -6.1735
# 877    Topic4   2.371548         senator_rubio  13.599000  -0.2241  -6.0633
# 1530   Topic4   1.536834       law_enforcement   6.965442   0.0111  -6.4971
# 2083   Topic4   1.169695       make_difference   2.083633   0.9449  -6.7701
# 833    Topic4   1.148718           rubio_right   2.620802   0.6975  -6.7882
# 935    Topic4   1.133145        tapper_cameron   2.126294   0.8929  -6.8018
# 1365   Topic4   1.139846        broward_county   3.692088   0.3470  -6.7959
# 2041   Topic4   1.136470      background_check   6.498334  -0.2213  -6.7989
#
# [224 rows x 6 columns], token_table=      Topic      Freq                    Term
# term
# 2459      1  0.304629                 'd_like
# 2459      3  0.304629                 'd_like
# 2459      4  0.304629                 'd_like
# 818       1  0.237994           ..._crosstalk
# 818       3  0.237994           ..._crosstalk
# 818       4  0.475988           ..._crosstalk
# 3196      1  0.882288                  5k_run
# 2086      3  0.620368        absolutely_right
# 1470      3  0.620435             alex_killed
# 2930      4  0.644670            america_safe
# 3490      2  0.621595           annabel_quinn
# 2252      2  0.377122          assault_rifles
# 2252      4  0.377122          assault_rifles
# 400       2  0.466162          assault_weapon
# 400       3  0.466162          assault_weapon
# 2573      1  0.363851         assault_weapons
# 2573      3  0.363851         assault_weapons
# 2573      4  0.181926         assault_weapons
# 2041      1  0.307771        background_check
# 2041      2  0.307771        background_check
# 2041      3  0.307771        background_check
# 2041      4  0.153886        background_check
# 66        1  0.516012       background_checks
# 66        2  0.258006       background_checks
# 66        3  0.258006       background_checks
# 3222      1  0.366553               baker_act
# 3222      2  0.733105               baker_act
# 2097      1  0.591684             believe_law
# 3081      2  0.372645          believe_saying
# 3081      3  0.745289          believe_saying
# ...     ...       ...                     ...
# 973       1  0.883238            thank_coming
# 3696      4  0.644116       thank_congressman
# 173       2  0.621651               thank_mr.
# 3193      3  0.540706           thank_senator
# 3193      4  0.270353           thank_senator
# 617       1  0.591346         thing_separates
# 2426      1  0.591456             time_people
# 3829      3  0.622127         tonight_quality
# 2595      3  0.462258  totality_circumstances
# 2315      1  0.513941               town_hall
# 2315      2  0.256970               town_hall
# 1484      2  0.621648         trump_suggested
# 1216      1  0.184975     unidentified_female
# 1216      2  0.184975     unidentified_female
# 1216      3  0.554925     unidentified_female
# 1216      4  0.184975     unidentified_female
# 459       3  0.620507    universal_background
# 685       3  0.620481             wait_second
# 3966      1  0.591440  washington_tallahassee
# 1957      4  0.638391              watch_list
# 2164      1  0.455799             weapons_ban
# 2164      3  0.455799             weapons_ban
# 2164      4  0.227900             weapons_ban
# 483       1  0.447395             welcome_cnn
# 483       2  0.447395             welcome_cnn
# 1360      3  0.620485             white_house
# 3763      2  0.621610                year_old
# 2490      2  0.621653             years_later
# 3919      3  0.620522               years_old
# 2864      3  0.620503             years_years
#
# [260 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 4, 3, 1])

# %%
f = open("ldadvis.html", "w")
pyLDAvis.save_html(pyLDAvis.gensim.prepare(lda, corpus, dictionary_biphrases), f)
# Out:
# /anaconda2/lib/python2.7/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
